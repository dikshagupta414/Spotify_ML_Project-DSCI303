# %%
import pandas as pd
import numpy as np
import sklearn as sklearn
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from sklearn.manifold import TSNE
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../archive/final_data.csv')
df.head()
# Out:
#    Unnamed: 0  acousticness                                   artists  \
# 0           0         0.995                       ['Carl Woitschach']
# 1           1         0.994  ['Robert Schumann', 'Vladimir Horowitz']
# 2           2         0.604                   ['Seweryn Goszczyński']
# 3           3         0.995                      ['Francisco Canaro']
# 4           4         0.990  ['Frédéric Chopin', 'Vladimir Horowitz']
#
#    danceability  duration_ms  energy  explicit                      id  \
# 0         0.708       158648  0.1950         0  6KbQ3uYMLKb5jDxLF7wYDD
# 1         0.379       282133  0.0135         0  6KuQTIu1KoTTkLXKrwlLPV
# 2         0.749       104300  0.2200         0  6L63VW0PibdM1HDSBoqnoM
# 3         0.781       180760  0.1300         0  6M94FkXd15sOAOQYRnWPN8
# 4         0.210       687733  0.2040         0  6N6tiFZ9vLTSOIxkj8qKrd
#
#    instrumentalness  key  ...                                           name  \
# 0             0.563   10  ...                    Singende Bataillone 1. Teil
# 1             0.901    8  ...       Fantasiestücke, Op. 111: Più tosto lento
# 2             0.000    5  ...                 Chapter 1.18 - Zamek kaniowski
# 3             0.887    1  ...  Bebamos Juntos - Instrumental (Remasterizado)
# 4             0.908   11  ...    Polonaise-Fantaisie in A-Flat Major, Op. 61
#
#    popularity  release_date speechiness    tempo valence  year  loudness_norm  \
# 0           0          1928      0.0506  118.469  0.7790  1928      -0.186652
# 1           0          1928      0.0462   83.972  0.0767  1928      -3.014729
# 2           0          1928      0.9290  107.177  0.8800  1928      -1.509457
# 3           0    1928-09-25      0.0926  108.003  0.7200  1928      -0.593587
# 4           1          1928      0.0424   62.149  0.0693  1928      -0.963288
#
#    temp_norm  year_bins
# 0   0.049500          0
# 1  -1.073199          0
# 2  -0.317996          0
# 3  -0.291114          0
# 4  -1.783425          0
#
# [5 rows x 23 columns]

# %%
train, test = train_test_split(df, test_size = 0.1, stratify=df['year_bins'])
# Out:
# 152918
